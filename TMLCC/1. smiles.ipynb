# %% [markdown]
# # Start

# %%
path="/content/drive/MyDrive/Wanchem colab/Final colab /"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q condacolab

# %%
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda install openbabel
# Out:
# done
# done
#
# # All requested packages already installed.

# %%
from openbabel import pybel

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ##trian smiles

# %%
data=pd.read_csv(path+"train.csv")

# %%
data=data[~((data["surface_area [m^2/g]"]==0) | (data["void_fraction"]==0))]

# %%
def s_cif(x):
  return x.split(".")[0]

# %%
file=data["MOFname"].values

# %%
len(file)
# Out:
# 54130

# %%
# !unzip "/content/drive/MyDrive/Wanchem colab/Final colab /mof_cif_train.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: mof_cif_train/mof_unit_11710.cif
#   inflating: mof_cif_train/mof_unit_49820.cif
#   inflating: mof_cif_train/mof_unit_68055.cif
#   inflating: mof_cif_train/mof_unit_31870.cif
#   inflating: mof_cif_train/mof_unit_10972.cif
#   inflating: mof_cif_train/mof_unit_51376.cif
#   inflating: mof_cif_train/mof_unit_29570.cif
#   inflating: mof_cif_train/mof_unit_13836.cif
#   inflating: mof_cif_train/mof_unit_26769.cif
#   inflating: mof_cif_train/mof_unit_17796.cif
#   inflating: mof_cif_train/mof_unit_60133.cif
#   inflating: mof_cif_train/mof_unit_46240.cif
#   inflating: mof_cif_train/mof_unit_1425.cif
#   inflating: mof_cif_train/mof_unit_68431.cif
#   inflating: mof_cif_train/mof_unit_33903.cif
#   inflating: mof_cif_train/mof_unit_38177.cif
#   inflating: mof_cif_train/mof_unit_41144.cif
#   inflating: mof_cif_train/mof_unit_63234.cif
#   inflating: mof_cif_train/mof_unit_29098.cif
# ...

# %%
def cif_to_smiles(fname):
    try:
      mol = next(pybel.readfile("cif", fname))
      smi = mol.write(format="smiles")
      return smi.split()[0].strip()
    except:
      return np.nan

# %%
def add_path(fp):
  path="/content/mof_cif_train/"
  return path+fp+".cif"

# %%
data["path"]=data[["MOFname"]].apply(add_path)

# %%
data["smiles"]=""
for i in range(0,len(data)):
    data["smiles"][i]=cif_to_smiles(data["path"][i])
    if i%1000==0:
        data=data.dropna()
        data.to_csv(path+"train_with_smiles.csv")
data=data.dropna()
data.to_csv(path+"train_with_smiles.csv")
# Out:
# 0
# mof_unit_28734
# 1
# mof_unit_56024
# 2
# mof_unit_40572
# 3
# mof_unit_44986
# 4
# mof_unit_49856
# 5
# mof_unit_35235
# 6
# mof_unit_45215
# 7
# mof_unit_43339
# 8
# mof_unit_64782
# 9
# mof_unit_47665
# 10
# mof_unit_17492
# 11
# mof_unit_19173
# 12
# mof_unit_32363
# 13
# mof_unit_38974
# 14
# mof_unit_49218
# 15
# mof_unit_54951
# 16
# mof_unit_53843
# 17
# mof_unit_48363
# 18
# mof_unit_51382
# 19
# mof_unit_21624
# 20
# mof_unit_15892
# 21
# mof_unit_61867
# 22
# mof_unit_29710
# 23
# mof_unit_10725
# 24
# mof_unit_60385
# 25
# mof_unit_18301
# 26
# mof_unit_1099
# 27
# mof_unit_34307
# 28
# mof_unit_4634
# 29
# mof_unit_38969
# 30
# mof_unit_6764
# 31
# mof_unit_41416
# 32
# mof_unit_37579
# 33
# mof_unit_17830
# 34
# mof_unit_57723
# 35
# mof_unit_28594
# 36
# mof_unit_39070
# 37
# mof_unit_27092
# 38
# mof_unit_33740
# 39
# mof_unit_47581
# 40
# mof_unit_58142
# 41
# mof_unit_49996
# 42
# mof_unit_40289
# 43
# mof_unit_26873
# 44
# mof_unit_20788
# 45
# mof_unit_34569
# ...

# %%
data=pd.read_csv(path+"train_with_smiles.csv")
data=data.drop(columns="path")
data.to_csv(path+"train_with_smiles.csv")

# %% [markdown]
# ##test smiles

# %%
data=pd.read_csv(path+"test.csv")

# %%
data=data[~((data["surface_area [m^2/g]"]==0) | (data["void_fraction"]==0))]

# %%
def s_cif(x):
  return x.split(".")[0]

# %%
file=data["MOFname"].values

# %%
len(file)
# Out:
# 54130

# %%
# !unzip "/content/drive/MyDrive/Wanchem colab/Final colab /mof_cif_test.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: mof_cif_train/mof_unit_11710.cif
#   inflating: mof_cif_train/mof_unit_49820.cif
#   inflating: mof_cif_train/mof_unit_68055.cif
#   inflating: mof_cif_train/mof_unit_31870.cif
#   inflating: mof_cif_train/mof_unit_10972.cif
#   inflating: mof_cif_train/mof_unit_51376.cif
#   inflating: mof_cif_train/mof_unit_29570.cif
#   inflating: mof_cif_train/mof_unit_13836.cif
#   inflating: mof_cif_train/mof_unit_26769.cif
#   inflating: mof_cif_train/mof_unit_17796.cif
#   inflating: mof_cif_train/mof_unit_60133.cif
#   inflating: mof_cif_train/mof_unit_46240.cif
#   inflating: mof_cif_train/mof_unit_1425.cif
#   inflating: mof_cif_train/mof_unit_68431.cif
#   inflating: mof_cif_train/mof_unit_33903.cif
#   inflating: mof_cif_train/mof_unit_38177.cif
#   inflating: mof_cif_train/mof_unit_41144.cif
#   inflating: mof_cif_train/mof_unit_63234.cif
#   inflating: mof_cif_train/mof_unit_29098.cif
# ...

# %%
def cif_to_smiles(fname):
    try:
      mol = next(pybel.readfile("cif", fname))
      smi = mol.write(format="smiles")
      return smi.split()[0].strip()
    except:
      return np.nan

# %%
def add_path(fp):
  path="/content/mof_cif_test/"
  return path+fp+".cif"

# %%
data["path"]=data[["MOFname"]].apply(add_path)

# %%
data["smiles"]=""
for i in range(0,len(data)):
    data["smiles"][i]=cif_to_smiles(data["path"][i])
    if i%1000==0:
        data=data.dropna()
        data.to_csv(path+"test_with_smiles.csv")
data=data.dropna()
data.to_csv(path+"test_with_smiles.csv")
# Out:
# 0
# mof_unit_28734
# 1
# mof_unit_56024
# 2
# mof_unit_40572
# 3
# mof_unit_44986
# 4
# mof_unit_49856
# 5
# mof_unit_35235
# 6
# mof_unit_45215
# 7
# mof_unit_43339
# 8
# mof_unit_64782
# 9
# mof_unit_47665
# 10
# mof_unit_17492
# 11
# mof_unit_19173
# 12
# mof_unit_32363
# 13
# mof_unit_38974
# 14
# mof_unit_49218
# 15
# mof_unit_54951
# 16
# mof_unit_53843
# 17
# mof_unit_48363
# 18
# mof_unit_51382
# 19
# mof_unit_21624
# 20
# mof_unit_15892
# 21
# mof_unit_61867
# 22
# mof_unit_29710
# 23
# mof_unit_10725
# 24
# mof_unit_60385
# 25
# mof_unit_18301
# 26
# mof_unit_1099
# 27
# mof_unit_34307
# 28
# mof_unit_4634
# 29
# mof_unit_38969
# 30
# mof_unit_6764
# 31
# mof_unit_41416
# 32
# mof_unit_37579
# 33
# mof_unit_17830
# 34
# mof_unit_57723
# 35
# mof_unit_28594
# 36
# mof_unit_39070
# 37
# mof_unit_27092
# 38
# mof_unit_33740
# 39
# mof_unit_47581
# 40
# mof_unit_58142
# 41
# mof_unit_49996
# 42
# mof_unit_40289
# 43
# mof_unit_26873
# 44
# mof_unit_20788
# 45
# mof_unit_34569
# ...

# %%
data=pd.read_csv(path+"test_with_smiles.csv")
data=data.drop(columns="path")
data.to_csv(path+"test_with_smiles.csv")
